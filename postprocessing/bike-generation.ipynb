# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob

# %%
#Import files
os.chdir("/Users/naroacorettisanchez/Documents/GitHub/MultifunctionalVehicleFleets/results/ MIXED_SS_fixedfleet")
#os.chdir("/Users/naroacorettisanchez/Documents/GitHub/MultifunctionalVehicleFleets/results/38reps_MIXED_fullData_final")

extension = 'csv'

#Bike tasks
filenames =[i for i in glob.glob('autonomousBike_trip_event*.{}'.format(extension))]

#Create a list with the dataframes in filenames
dfs = []
for filename in filenames:
    df_tasks = pd.read_csv(filename)
    dfs.append(df_tasks)

# %%
dfs[0].head()
# Out:
#    Cycle  Day      Time  NumBikes  Battery  AutDrivingSpeed  MaxBiddingTime  \
# 0      1    1  00:00:05       475  70000.0              8.0             0.5
# 1      1    1  00:00:05       475  70000.0              8.0             0.5
# 2      1    1  00:00:05       475  70000.0              8.0             0.5
# 3      1    1  00:00:05       475  70000.0              8.0             0.5
# 4      1    1  00:00:05       475  70000.0              8.0             0.5
#
#    UrgencyPerson  UrgencyPackage  UrgencyWeight  ...             Event  \
# 0              1               0           0.25  ...  START: wandering
# 1              1               0           0.25  ...  START: wandering
# 2              1               0           0.25  ...  START: wandering
# 3              1               0           0.25  ...  START: wandering
# 4              1               0           0.25  ...  START: wandering
#
#    Activity Message Start Time  End Time Duration (min) Distance Traveled  \
# 0         0     nil        NaN       NaN            NaN               NaN
# 1         0     nil        NaN       NaN            NaN               NaN
# 2         0     nil        NaN       NaN            NaN               NaN
# 3         0     nil        NaN       NaN            NaN               NaN
# 4         0     nil        NaN       NaN            NaN               NaN
#
#   Start Battery %  End Battery %  Battery Gain %
# 0             NaN            NaN             NaN
# 1             NaN            NaN             NaN
# 2             NaN            NaN             NaN
# 3             NaN            NaN             NaN
# 4             NaN            NaN             NaN
#
# [5 rows x 23 columns]
