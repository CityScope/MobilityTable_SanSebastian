# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob
from matplotlib.ticker import FuncFormatter
import numpy as np

# %%
os.chdir("/Users/naroacorettisanchez/Documents/GitHub/MultifunctionalVehicleFleets/results/2023-08-07 04.00.00")

# %%
extension = 'csv'

#Food rips
food_filenames =[i for i in glob.glob('package_trips_*.{}'.format(extension))]

#Vehicle tasks
bikes_filenames= [i for i in glob.glob('autonomousBike_trip_*.{}'.format(extension))]

# %%
df_total_food = []

for f in food_filenames:
 temp_f = pd.read_csv(f)
 df_total_food.append(temp_f)

# %%
df_total_bikes = []

for f in bikes_filenames:
 temp_f = pd.read_csv(f)
 df_total_bikes.append(temp_f)

df_bike = pd.read_csv(bikes_filenames[3])

print(bikes_filenames[3])
# Out:
# autonomousBike_trip_event16_41_56.csv

# %%
df_bike
# Out:
#         Cycle  Day      Time  NumBikes  Battery  AutDrivingSpeed  \
# 0           0    7  00:00:00       164  70000.0              8.0
# 1           0    7  00:00:00       164  70000.0              8.0
# 2           0    7  00:00:00       164  70000.0              8.0
# 3           0    7  00:00:00       164  70000.0              8.0
# 4           0    7  00:00:00       164  70000.0              8.0
# ...       ...  ...       ...       ...      ...              ...
# 186239  20094   13  23:27:00       306  70000.0              8.0
# 186240  20095   13  23:27:30       306  70000.0              8.0
# 186241  20095   13  23:27:30       306  70000.0              8.0
# 186242  20101   13  23:30:30       306  70000.0              8.0
# 186243  20102   13  23:31:00       306  70000.0              8.0
#
#         MaxBiddingTime  PackBidCt  PackBidDist  PackBidQueue  ...  \
# 0                    0      100.0         0.01           2.0  ...
# 1                    0      100.0         0.01           2.0  ...
# 2                    0      100.0         0.01           2.0  ...
# 3                    0      100.0         0.01           2.0  ...
# 4                    0      100.0         0.01           2.0  ...
# ...                ...        ...          ...           ...  ...
# 186239               0      100.0         0.01           2.0  ...
# 186240               0      100.0         0.01           2.0  ...
# 186241               0      100.0         0.01           2.0  ...
# 186242               0      100.0         0.01           2.0  ...
# 186243               0      100.0         0.01           2.0  ...
#
#                        Event  Activity             Message Start Time  \
# 0           START: wandering         0                 nil        NaN
# 1           START: wandering         0                 nil        NaN
# 2           START: wandering         0                 nil        NaN
# 3           START: wandering         0                 nil        NaN
# 4           START: wandering         0                 nil        NaN
# ...                      ...       ...                 ...        ...
# 186239  END: in_use_packages         0  Usedpackage(30076)   23:16:30
# 186240      START: wandering         0                 nil        NaN
# 186241      START: wandering         0                 nil        NaN
# 186242  END: in_use_packages         0  Usedpackage(30077)   23:17:00
# 186243      START: wandering         0                 nil        NaN
#
#         End Time  Duration (min) Distance Traveled Start Battery %  \
# 0            NaN             NaN               NaN             NaN
# 1            NaN             NaN               NaN             NaN
# 2            NaN             NaN               NaN             NaN
# 3            NaN             NaN               NaN             NaN
# 4            NaN             NaN               NaN             NaN
# ...          ...             ...               ...             ...
# 186239  23:27:00            10.5       1333.445317       86.694846
# 186240       NaN             NaN               NaN             NaN
# 186241       NaN             NaN               NaN             NaN
# 186242  23:30:30            13.5       1738.252646       97.233672
# 186243       NaN             NaN               NaN             NaN
#
#        End Battery %  Battery Gain %
# 0                NaN             NaN
# 1                NaN             NaN
# 2                NaN             NaN
# 3                NaN             NaN
# 4                NaN             NaN
# ...              ...             ...
# 186239     84.585765       -2.109081
# 186240           NaN             NaN
# 186241           NaN             NaN
# 186242     94.684441       -2.549231
# 186243           NaN             NaN
#
# [186244 rows x 24 columns]

# %%
# Extract the day from the 'starttime' column
df_bike['Day'] = df_bike['Day'] - 6

# Round down 'start_time' column to nearest 15 minutes
df_bike['start_time_ed'] = pd.to_datetime(df_bike['Time']).dt.floor('15Min')

# Group the data by day and 15-minute intervals and count the number of rows
counts_activities= df_bike.groupby(['Day', 'start_time_ed','Event']).size().reset_index(name='count')

# Format the datetime columns
counts_activities['x_datetime'] = counts_activities['Day'].astype(str) + ', ' + counts_activities['start_time_ed'].dt.strftime('%H:%M:%S')

# %%
counts_activities
# Out:
#       Day       start_time_ed                       Event  count   x_datetime
# 0       1 2023-08-10 00:00:00            START: wandering    164  1, 00:00:00
# 1       1 2023-08-10 01:15:00    END: picking_up_packages      1  1, 01:15:00
# 2       1 2023-08-10 01:15:00              END: wandering      1  1, 01:15:00
# 3       1 2023-08-10 01:15:00      START: in_use_packages      1  1, 01:15:00
# 4       1 2023-08-10 01:15:00  START: picking_up_packages      1  1, 01:15:00
# ...   ...                 ...                         ...    ...          ...
# 4110    7 2023-08-10 23:15:00      START: in_use_packages      4  7, 23:15:00
# 4111    7 2023-08-10 23:15:00  START: picking_up_packages      1  7, 23:15:00
# 4112    7 2023-08-10 23:15:00            START: wandering      4  7, 23:15:00
# 4113    7 2023-08-10 23:30:00        END: in_use_packages      1  7, 23:30:00
# 4114    7 2023-08-10 23:30:00            START: wandering      1  7, 23:30:00
#
# [4115 rows x 5 columns]

# %%
# Create a DataFrame with one row every 15 minutes for 7 days
days = pd.Series(range(1, 8))
time_intervals = pd.date_range(start='00:00:00', end='23:59:59', freq='15Min')
index = pd.MultiIndex.from_product([days, time_intervals], names=['day', 'start_time_ed'])
df_counts_activities= pd.DataFrame(index=index).reset_index()

# %%
# Set the index of df_counts_food
df_counts_activities['x_datetime'] = df_counts_activities['day'].astype(str) + ', ' + df_counts_activities['start_time_ed'].dt.strftime('%H:%M:%S')

# %%
# Merge the counts with the complete DataFrame to fill missing values with zeros
df_counts_activities= pd.merge(df_counts_activities, counts_activities[['x_datetime', 'count', 'Event']], how='left', left_on=['x_datetime'], right_on=['x_datetime']).fillna({'count': 0})

# %%
# Pivot the table to have x_datetime as index, Event types as columns, and counts as values
pivot_table = df_counts_activities.pivot(index='x_datetime', columns='Event', values='count')

# Plot the pivot_table
pivot_table.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Event Counts by Datetime')
plt.xlabel('Datetime')
plt.ylabel('Event Count')
plt.legend(title='Event Type')
plt.show()

# %%
event_types = df_counts_activities['Event'].unique()
print(event_types)
# Out:
# ['START: wandering' nan 'END: picking_up_packages' 'END: wandering'
#  'START: in_use_packages' 'START: picking_up_packages'
#  'END: in_use_packages' 'END: low_battery' 'START: low_battery']

# %%
# Separate the data for each Event type
event_types = df_counts_activities['Event'].unique()
#event_types = ['START: low_battery']

# Create a plot
plt.figure(figsize=(20, 6))

# Plot lines for each Event type
for event_type in event_types:
    event_data = counts_activities[counts_activities['Event'] == event_type]
    plt.plot(event_data['x_datetime'], event_data['count'], label=event_type, linewidth=1)

# Extract the last 8 digits of x_datetime for tick labels
tick_labels = [label[-8:-3] for label in counts_activities['x_datetime'][::8]]

# Set the x-axis tick labels and rotation
plt.xticks(counts_activities['x_datetime'][::8], tick_labels, rotation=90)

# Set the axis labels and title
plt.xlabel('Time (HH:mm)', fontsize=8)
plt.ylabel('Number of Events', fontsize=12)
plt.title('Event Count Over Time', fontsize=14)

# Customize the grid
plt.grid(color='lightgray', linestyle='--')

# Customize the plot background and border
plt.gca().set_facecolor('white')
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Adjust the tick parameters
plt.tick_params(axis='both', which='both', bottom=True, top=False, left=True, right=False)

# Add a legend
plt.legend(loc='best')

# Adjust the layout for better spacing
#plt.tight_layout()

# Display the plot
plt.show()

# %%
# Format the datetime columns
df_bike['Time_ed'] = df_bike['Day'].astype(str) + ', ' + df_bike['start_time_ed'].dt.strftime('%H:%M:%S')

# %%
idle=df_bike.loc[(df_bike['Event']== 'END: wandering') | (df_bike['Event']== 'START: wandering')]
df=idle
count=0

idle_count = pd.DataFrame(columns=['Time', 'Count'])
    
for i,row in df.iterrows():
    
    event = row["Event"]
    if event == 'END: wandering':
        count=count-1
    elif event== 'START: wandering':
        count=count+1
    else:
        print('Event type error')
    idle_count.loc[i] = [row['Time_ed']] + [count]

idle_count.plot(x='Time', y='Count', kind='line',title="Idle")
# Out:
# <AxesSubplot:title={'center':'Idle'}, xlabel='Time'>

# %%
use=df_bike.loc[(df_bike['Event']== 'END: in_use_packages') | (df_bike['Event']== 'START: in_use_packages')]
df=use
count=0

use_count = pd.DataFrame(columns=['Time', 'Count'])
    
for i,row in df.iterrows():
    
    event = row["Event"]
    if event == 'END: in_use_packages':
        count=count-1
    elif event== 'START: in_use_packages':
        count=count+1
    else:
        print('Event type error')
    use_count.loc[i] = [row['Time_ed']] + [count]

use_count.plot(x='Time', y='Count', kind='line',title="Use")
# Out:
# <AxesSubplot:title={'center':'Use'}, xlabel='Time'>

# %%
charging=df_bike.loc[(df_bike['Event']== 'END: low_battery') | (df_bike['Event']== 'START: low_battery')]
df=charging
count=0

charging_count = pd.DataFrame(columns=['Time', 'Count'])
    
for i,row in df.iterrows():
    
    event = row["Event"]
    if event == 'END: low_battery':
        count=count-1
    elif event== 'START: low_battery':
        count=count+1
    else:
        print('Event type error')
    charging_count.loc[i] = [row['Time_ed']] + [count]

charging_count.plot(x='Time', y='Count', kind='line',title="Charge")
# Out:
# <AxesSubplot:title={'center':'Charge'}, xlabel='Time'>

# %%
pick=df_bike.loc[(df_bike['Event']== 'END: picking_up_packages') | (df_bike['Event']== 'START: picking_up_packages')]
df=pick
count=0

pick_count = pd.DataFrame(columns=['Time', 'Count'])
    
for i,row in df.iterrows():
    
    event = row["Event"]
    if event == 'END: picking_up_packages':
        count=count-1
    elif event== 'START: picking_up_packages':
        count=count+1
    else:
        print('Event type error')
    pick_count.loc[i] = [row['Time_ed']] + [count]

pick_count.plot(x='Time', y='Count', kind='line',title="Pick-up")
# Out:
# <AxesSubplot:title={'center':'Pick-up'}, xlabel='Time'>

# %%
len(idle_count)
# Out:
# 63196

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Assuming you have DataFrames named idle_count, use_count, pick_count, charging_count

# Create a plot
plt.figure(figsize=(20, 6))

# Extract the last 8 digits of x_datetime for tick labels
#tick_labels = [label[-8:-3] for label in idle_count['Time'][::8]]

# Multiple line plots
plt.plot('Time', 'Count', data=idle_count, color='orange', label="idle")
plt.plot('Time', 'Count', data=use_count, color='olive', label="use")
plt.plot('Time', 'Count', data=pick_count, color='green', label="pickup")
plt.plot('Time', 'Count', data=charging_count, color='red', label="charge")

# Set the axis labels and title
plt.xlabel('Day, Time (HH:mm)', fontsize=8)
plt.ylabel('Event Count', fontsize=12)
plt.title('Event Count Over Time', fontsize=14)

# Customize the grid
plt.grid(color='lightgray', linestyle='--')

# Customize the plot background and border
plt.gca().set_facecolor('white')
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Show legend
plt.legend(loc='best')

# Rotate x-axis tick labels for better readability
plt.xticks(rotation=45, ha='right')

# Adjust the tick parameters
plt.tick_params(axis='both', which='both', bottom=True, top=False, left=True, right=False)


# Show every 20th tick
plt.gca().xaxis.set_major_locator(plt.MaxNLocator(integer=True, prune='both', nbins=99))

# Show the plot
plt.tight_layout()  # Adjust layout for better spacing
plt.show()

# %%
df_bike.columns
# Out:
# Index(['Cycle', 'Day', 'Time', 'NumBikes', 'Battery', 'AutDrivingSpeed',
#        'MaxBiddingTime', 'PackBidCt', 'PackBidDist', 'PackBidQueue',
#        'PersonBidCt', 'PersonBidDist', 'PersonBidQueue', 'Agent', 'Event',
#        'Activity', 'Message', 'Start Time', 'End Time', 'Duration (min)',
#        'Distance Traveled', 'Start Battery %', 'End Battery %',
#        'Battery Gain %', 'start_time_ed', 'Time_ed'],
#       dtype='object')

# %%
all_bikenames = df_bike['Agent'].unique()
last_rows_bikes  =  pd.DataFrame()

for bike in all_bikenames:
    bike_rows= df_bike[df_bike['Agent']==bike]
    last_row = bike_rows.iloc[-1]
    print(last_row)
    last_rows_bikes= last_rows_bikes.append(last_row)
# Out:
# Cycle                              20008
# Day                                    7
# Time                            22:44:00
# NumBikes                             306
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                    autonomousBike0
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 22:30:00
# Time_ed                      7, 22:30:00
# Name: 186133, dtype: object
# Cycle                              19811
# Day                                    7
# Time                            21:05:30
# NumBikes                             306
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                    autonomousBike1
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 21:00:00
# Time_ed                      7, 21:00:00
# Name: 185248, dtype: object
# Cycle                               4877
# Day                                    2
# Time                            16:38:30
# NumBikes                             286
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                    autonomousBike2
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 16:30:00
# Time_ed                      2, 16:30:00
# Name: 54485, dtype: object
# Cycle                               4416
# Day                                    2
# Time                            12:48:00
# NumBikes                             286
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                    autonomousBike3
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 12:45:00
# Time_ed                      2, 12:45:00
# Name: 42330, dtype: object
# Cycle                              16622
# Day                                    6
# Time                            18:31:00
# NumBikes                             301
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                    autonomousBike4
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 18:30:00
# Time_ed                      6, 18:30:00
# Name: 156957, dtype: object
# Cycle                              13469
# Day                                    5
# Time                            16:14:30
# NumBikes                             294
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                    autonomousBike5
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 16:00:00
# Time_ed                      5, 16:00:00
# Name: 127652, dtype: object
# Cycle                              16132
# Day                                    6
# Time                            14:26:00
# NumBikes                             301
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                    autonomousBike6
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 14:15:00
# Time_ed                      6, 14:15:00
# Name: 148107, dtype: object
# Cycle                              19879
# Day                                    7
# Time                            21:39:30
# NumBikes                             306
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                    autonomousBike7
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 21:30:00
# Time_ed                      7, 21:30:00
# Name: 185750, dtype: object
# Cycle                              15938
# Day                                    6
# Time                            12:49:00
# NumBikes                             301
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                    autonomousBike8
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 12:45:00
# Time_ed                      6, 12:45:00
# Name: 144755, dtype: object
# Cycle                              12901
# Day                                    5
# Time                            11:30:30
# NumBikes                             288
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                    autonomousBike9
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 11:30:00
# Time_ed                      5, 11:30:00
# Name: 117254, dtype: object
# Cycle                               1644
# Day                                    1
# Time                            13:42:00
# NumBikes                             257
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                   autonomousBike10
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 13:30:00
# Time_ed                      1, 13:30:00
# Name: 14175, dtype: object
# Cycle                              20081
# Day                                    7
# Time                            23:20:30
# NumBikes                             306
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                   autonomousBike11
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 23:15:00
# Time_ed                      7, 23:15:00
# Name: 186231, dtype: object
# Cycle                              10864
# Day                                    4
# Time                            18:32:00
# NumBikes                             288
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                   autonomousBike12
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 18:30:00
# Time_ed                      4, 18:30:00
# Name: 107663, dtype: object
# Cycle                               4853
# Day                                    2
# Time                            16:26:30
# NumBikes                             286
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                   autonomousBike13
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 16:15:00
# Time_ed                      2, 16:15:00
# Name: 54080, dtype: object
# Cycle                              19949
# Day                                    7
# Time                            22:14:30
# NumBikes                             306
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                   autonomousBike14
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 22:00:00
# Time_ed                      7, 22:00:00
# Name: 186027, dtype: object
# Cycle                              19805
# Day                                    7
# Time                            21:02:30
# NumBikes                             306
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                   autonomousBike15
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 21:00:00
# Time_ed                      7, 21:00:00
# Name: 185196, dtype: object
# Cycle                              19256
# Day                                    7
# Time                            16:28:00
# NumBikes                             306
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                   autonomousBike16
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 16:15:00
# Time_ed                      7, 16:15:00
# Name: 177369, dtype: object
# Cycle                              20102
# Day                                    7
# Time                            23:31:00
# NumBikes                             306
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                   autonomousBike17
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 23:30:00
# Time_ed                      7, 23:30:00
# Name: 186243, dtype: object
# Cycle                              10877
# Day                                    4
# Time                            18:38:30
# NumBikes                             288
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                   autonomousBike18
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 18:30:00
# Time_ed                      4, 18:30:00
# Name: 107940, dtype: object
# Cycle                              19834
# Day                                    7
# Time                            21:17:00
# NumBikes                             306
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                   autonomousBike19
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 21:15:00
# Time_ed                      7, 21:15:00
# Name: 185483, dtype: object
# Cycle                              10578
# Day                                    4
# Time                            16:09:00
# NumBikes                             288
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                   autonomousBike20
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 16:00:00
# Time_ed                      4, 16:00:00
# Name: 102823, dtype: object
# Cycle                              19879
# Day                                    7
# Time                            21:39:30
# NumBikes                             306
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                   autonomousBike21
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 21:30:00
# Time_ed                      7, 21:30:00
# Name: 185751, dtype: object
# Cycle                              20038
# Day                                    7
# Time                            22:59:00
# NumBikes                             306
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                   autonomousBike22
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 22:45:00
# Time_ed                      7, 22:45:00
# Name: 186197, dtype: object
# Cycle                              12367
# Day                                    5
# Time                            07:03:30
# NumBikes                             288
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                   autonomousBike23
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 07:00:00
# Time_ed                      5, 07:00:00
# Name: 112661, dtype: object
# Cycle                              19735
# Day                                    7
# Time                            20:27:30
# NumBikes                             306
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                   autonomousBike24
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 20:15:00
# Time_ed                      7, 20:15:00
# Name: 184607, dtype: object
# Cycle                              20018
# Day                                    7
# Time                            22:49:00
# NumBikes                             306
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                   autonomousBike25
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 22:45:00
# Time_ed                      7, 22:45:00
# Name: 186159, dtype: object
# Cycle                              19135
# Day                                    7
# Time                            15:27:30
# NumBikes                             306
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                   autonomousBike26
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 15:15:00
# Time_ed                      7, 15:15:00
# Name: 175150, dtype: object
# Cycle                              10630
# Day                                    4
# Time                            16:35:00
# NumBikes                             288
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                   autonomousBike27
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 16:30:00
# Time_ed                      4, 16:30:00
# Name: 103632, dtype: object
# Cycle                               8176
# Day                                    3
# Time                            20:08:00
# NumBikes                             286
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                   autonomousBike28
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 20:00:00
# Time_ed                      3, 20:00:00
# Name: 85566, dtype: object
# Cycle                               4477
# Day                                    2
# Time                            13:18:30
# NumBikes                             286
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                   autonomousBike29
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 13:15:00
# Time_ed                      2, 13:15:00
# Name: 44218, dtype: object
# Cycle                              19695
# Day                                    7
# Time                            20:07:30
# NumBikes                             306
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                   autonomousBike30
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 20:00:00
# Time_ed                      7, 20:00:00
# Name: 184201, dtype: object
# Cycle                              18612
# Day                                    7
# Time                            11:06:00
# NumBikes                             301
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                   autonomousBike31
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 11:00:00
# Time_ed                      7, 11:00:00
# Name: 165862, dtype: object
# Cycle                              19608
# Day                                    7
# Time                            19:24:00
# NumBikes                             306
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                   autonomousBike32
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 19:15:00
# Time_ed                      7, 19:15:00
# Name: 183259, dtype: object
# Cycle                              19923
# Day                                    7
# Time                            22:01:30
# NumBikes                             306
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                   autonomousBike33
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 22:00:00
# Time_ed                      7, 22:00:00
# Name: 185963, dtype: object
# Cycle                              19863
# Day                                    7
# Time                            21:31:30
# NumBikes                             306
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                   autonomousBike34
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 21:30:00
# Time_ed                      7, 21:30:00
# Name: 185672, dtype: object
# Cycle                              19719
# Day                                    7
# Time                            20:19:30
# NumBikes                             306
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                   autonomousBike35
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 20:15:00
# Time_ed                      7, 20:15:00
# Name: 184479, dtype: object
# Cycle                              19826
# Day                                    7
# Time                            21:13:00
# NumBikes                             306
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                   autonomousBike36
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 21:00:00
# Time_ed                      7, 21:00:00
# Name: 185427, dtype: object
# Cycle                              10671
# Day                                    4
# Time                            16:55:30
# NumBikes                             288
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                   autonomousBike37
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 16:45:00
# Time_ed                      4, 16:45:00
# Name: 104342, dtype: object
# Cycle                               4993
# Day                                    2
# Time                            17:36:30
# NumBikes                             286
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                   autonomousBike38
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 17:30:00
# Time_ed                      2, 17:30:00
# Name: 56569, dtype: object
# Cycle                              19937
# Day                                    7
# Time                            22:08:30
# NumBikes                             306
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                   autonomousBike39
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 22:00:00
# Time_ed                      7, 22:00:00
# Name: 186001, dtype: object
# Cycle                              19711
# Day                                    7
# Time                            20:15:30
# NumBikes                             306
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                   autonomousBike40
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 20:15:00
# Time_ed                      7, 20:15:00
# Name: 184398, dtype: object
# Cycle                               6591
# Day                                    3
# Time                            06:55:30
# NumBikes                             286
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                   autonomousBike41
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 06:45:00
# Time_ed                      3, 06:45:00
# Name: 63348, dtype: object
# Cycle                              19662
# Day                                    7
# Time                            19:51:00
# NumBikes                             306
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                   autonomousBike42
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 19:45:00
# Time_ed                      7, 19:45:00
# Name: 183823, dtype: object
# Cycle                              16390
# Day                                    6
# Time                            16:35:00
# NumBikes                             301
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                   autonomousBike43
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# ...
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                  autonomousBike291
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 23:00:00
# Time_ed                      7, 23:00:00
# Name: 186207, dtype: object
# Cycle                              19529
# Day                                    7
# Time                            18:44:30
# NumBikes                             306
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                  autonomousBike292
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 18:30:00
# Time_ed                      7, 18:30:00
# Name: 182141, dtype: object
# Cycle                              19573
# Day                                    7
# Time                            19:06:30
# NumBikes                             306
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                  autonomousBike293
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 19:00:00
# Time_ed                      7, 19:00:00
# Name: 182820, dtype: object
# Cycle                              18743
# Day                                    7
# Time                            12:11:30
# NumBikes                             306
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                  autonomousBike294
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 12:00:00
# Time_ed                      7, 12:00:00
# Name: 167980, dtype: object
# Cycle                              19933
# Day                                    7
# Time                            22:06:30
# NumBikes                             306
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                  autonomousBike295
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 22:00:00
# Time_ed                      7, 22:00:00
# Name: 185989, dtype: object
# Cycle                              19707
# Day                                    7
# Time                            20:13:30
# NumBikes                             306
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                  autonomousBike296
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 20:00:00
# Time_ed                      7, 20:00:00
# Name: 184354, dtype: object
# Cycle                              19801
# Day                                    7
# Time                            21:00:30
# NumBikes                             306
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                  autonomousBike297
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 21:00:00
# Time_ed                      7, 21:00:00
# Name: 185171, dtype: object
# Cycle                              19795
# Day                                    7
# Time                            20:57:30
# NumBikes                             306
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                  autonomousBike298
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 20:45:00
# Time_ed                      7, 20:45:00
# Name: 185113, dtype: object
# Cycle                              19662
# Day                                    7
# Time                            19:51:00
# NumBikes                             306
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                  autonomousBike299
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 19:45:00
# Time_ed                      7, 19:45:00
# Name: 183827, dtype: object
# Cycle                              19707
# Day                                    7
# Time                            20:13:30
# NumBikes                             306
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                  autonomousBike300
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 20:00:00
# Time_ed                      7, 20:00:00
# Name: 184355, dtype: object
# Cycle                              19646
# Day                                    7
# Time                            19:43:00
# NumBikes                             306
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                  autonomousBike301
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 19:30:00
# Time_ed                      7, 19:30:00
# Name: 183664, dtype: object
# Cycle                              19382
# Day                                    7
# Time                            17:31:00
# NumBikes                             306
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                  autonomousBike302
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 17:30:00
# Time_ed                      7, 17:30:00
# Name: 179609, dtype: object
# Cycle                              19712
# Day                                    7
# Time                            20:16:00
# NumBikes                             306
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                  autonomousBike303
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 20:15:00
# Time_ed                      7, 20:15:00
# Name: 184414, dtype: object
# Cycle                              19941
# Day                                    7
# Time                            22:10:30
# NumBikes                             306
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                  autonomousBike304
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 22:00:00
# Time_ed                      7, 22:00:00
# Name: 186015, dtype: object
# Cycle                              19907
# Day                                    7
# Time                            21:53:30
# NumBikes                             306
# Battery                            70000
# AutDrivingSpeed                        8
# MaxBiddingTime                         0
# PackBidCt                            100
# PackBidDist                         0.01
# PackBidQueue                           2
# PersonBidCt                          200
# PersonBidDist                       0.01
# PersonBidQueue                         2
# Agent                  autonomousBike305
# Event                   START: wandering
# Activity                               0
# Message                              nil
# Start Time                           NaN
# End Time                             NaN
# Duration (min)                       NaN
# Distance Traveled                    NaN
# Start Battery %                      NaN
# End Battery %                        NaN
# Battery Gain %                       NaN
# start_time_ed        2023-08-10 21:45:00
# Time_ed                      7, 21:45:00
# Name: 185897, dtype: object

# %%
len(last_rows_bikes)
# Out:
# 306

# %%
last_rows_bikes.to_csv('/Users/naroacorettisanchez/Documents/GitHub/MultifunctionalVehicleFleets/results/2023-08-07 04.00.00/last_bike_actions.csv')
