# %%
#WEEKEND fist
import pandas as pd

df_food= pd.read_csv('/Users/naroacorettisanchez/Documents/GitHub/DataSS/Deliveries/delivery_demand_ss_1week.csv')

# %%
df_food
# Out:
#                start_time order_vertical order_final_status  \
# 0     2023-09-18 09:31:39           Food    DeliveredStatus
# 1     2023-09-18 10:04:56           Food    DeliveredStatus
# 2     2023-09-18 10:16:05           Food    DeliveredStatus
# 3     2023-09-18 10:22:29           Food    DeliveredStatus
# 4     2023-09-18 10:49:33           Food    DeliveredStatus
# ...                   ...            ...                ...
# 6276  2023-09-24 23:11:29           Food    DeliveredStatus
# 6277  2023-09-24 23:11:33           Food    DeliveredStatus
# 6278  2023-09-24 23:14:07           Food    DeliveredStatus
# 6279  2023-09-24 23:23:59           Food    DeliveredStatus
# 6280  2023-09-24 23:25:51           Food    DeliveredStatus
#
#       start_to_pickup_flight_distance_in_meters  \
# 0                                     143.59972
# 1                                    1199.57040
# 2                                     780.57480
# ...

# %%
df = df_food

# Define a dictionary to map old days to new days
day_mapping = {
    1: 3,
    2: 4,
    3: 5,
    4: 6,
    5: 7,
    6: 1,
    7: 2
}


df['day'] = df['day'].map(day_mapping)
# Out:
#                start_time order_vertical order_final_status  \
# 0     2023-09-20 09:31:39           Food    DeliveredStatus
# 1     2023-09-20 10:04:56           Food    DeliveredStatus
# 2     2023-09-20 10:16:05           Food    DeliveredStatus
# 3     2023-09-20 10:22:29           Food    DeliveredStatus
# 4     2023-09-20 10:49:33           Food    DeliveredStatus
# ...                   ...            ...                ...
# 6276  2023-09-19 23:11:29           Food    DeliveredStatus
# 6277  2023-09-19 23:11:33           Food    DeliveredStatus
# 6278  2023-09-19 23:14:07           Food    DeliveredStatus
# 6279  2023-09-19 23:23:59           Food    DeliveredStatus
# 6280  2023-09-19 23:25:51           Food    DeliveredStatus
#
#       start_to_pickup_flight_distance_in_meters  \
# 0                                     143.59972
# 1                                    1199.57040
# 2                                     780.57480
# ...

# %%
df.to_csv('/Users/naroacorettisanchez/Documents/GitHub/DataSS/Deliveries/delivery_demand_ss_weekendfirst.csv')
