# %%
#WEEKEND fist
import pandas as pd

df_food= pd.read_csv('/Users/naroacorettisanchez/Documents/GitHub/DataSS/Deliveries/delivery_demand_ss_1week_scattered.csv')
df_user= pd.read_csv('/Users/naroacorettisanchez/Documents/GitHub/DataSS/Rides/ride_demand_ss_1week_scattered.csv')

# %%
df_food
# Out:
#                start_time order_vertical order_final_status  \
# 0     2023-09-18 09:31:39           Food    DeliveredStatus
# 1     2023-09-18 10:04:56           Food    DeliveredStatus
# 2     2023-09-18 10:16:05           Food    DeliveredStatus
# 3     2023-09-18 10:22:29           Food    DeliveredStatus
# 4     2023-09-18 10:49:33           Food    DeliveredStatus
# ...                   ...            ...                ...
# 6494  2023-09-24 23:11:29           Food    DeliveredStatus
# 6495  2023-09-24 23:11:33           Food    DeliveredStatus
# 6496  2023-09-24 23:14:07           Food    DeliveredStatus
# 6497  2023-09-24 23:23:59           Food    DeliveredStatus
# 6498  2023-09-24 23:25:51           Food    DeliveredStatus
#
#       start_to_pickup_flight_distance_in_meters  \
# 0                                     143.59972
# 1                                    1199.57040
# 2                                     780.57480
# ...

# %%
df = df_food

# Define a dictionary to map old days to new days
day_mapping = {
    1: 4,
    2: 5,
    3: 6,
    4: 7,
    5: 1,
    6: 2,
    7: 3
}


df['day'] = df['day'].map(day_mapping)

# %%
df.to_csv('/Users/naroacorettisanchez/Documents/GitHub/DataSS/Deliveries/delivery_demand_ss_flipped_scattered.csv')

# %%
df_user
# Out:
#        Unnamed: 0  Unnamed: 0.1  ID_viaje Estado cerrado  Duracion  \
# 0               0        237518   1164530         NORMAL       489
# 1               1        237517   1164531         NORMAL       480
# 2               2        237516   1164532         NORMAL       274
# 3               3        237515   1164533         NORMAL       101
# 4               4        237514   1164534         NORMAL       306
# ...           ...           ...       ...            ...       ...
# 19293       19350        217450   1186178         NORMAL       230
# 19294       19351        217449   1186179         NORMAL       877
# 19295       19352        217448   1186180         NORMAL       216
# 19296       19353        217447   1186181         NORMAL       641
# 19297       19354        217446   1186182         NORMAL       229
#
#        Id de estacion de inicio      Fecha de inicio  \
# 0                            31  2022-09-19 06:00:00
# ...

# %%
df_user['starttime'] = pd.to_datetime(df_user['starttime'])
df_user['day'] = df_user['starttime'].dt.day

# %%
df = df_user

# Define a dictionary to map old days to new days
day_mapping = {
    1: 22,
    2: 23,
    3: 24,
    4: 25,
    5: 19,
    6: 20,
    7: 21
}


df['day'] = df['day'].map(day_mapping)

# %%
df.to_csv('/Users/naroacorettisanchez/Documents/GitHub/DataSS/Rides/ride_demand_ss_1week_scattered_fipped.csv')
